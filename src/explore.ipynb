# %% [markdown]
# # Explore here

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Verify if DATABASE_URL is loaded correctly
print("DATABASE_URL:", os.getenv('DATABASE_URL'))
# Out:
# DATABASE_URL: None

# %%
load_dotenv(dotenv_path='/path/to/your/.env')
# Out:
# False

# %%
import os
print("Current directory:", os.getcwd())
# Out:
# Current directory: /Users/mariannacastro/Desktop/4Geeks/proyectos/ML-web-app-using-Streamlit-Marianna/src

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Check if the DATABASE_URL is loaded
print("DATABASE_URL:", os.getenv('DATABASE_URL'))
# Out:
# DATABASE_URL: None
